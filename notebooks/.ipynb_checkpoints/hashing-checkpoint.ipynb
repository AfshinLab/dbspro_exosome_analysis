# %% [markdown]
# # Hashing & Pashing
#
# ## Reanalysis
# Merged samples 4+5 and 6+7 before running pipe. Made configs more stringent.
#
# Require two or more UMI per target
#
# //Pontus, 2021-11-16
#
# ### Info from Mahsan
# Set1: EGFR ABC01+CD9-ABC03
# Set2: EGFR ABC06+CD9-ABC12
#
# exo/bead ratio: 1:10
# Capture time: 10 min
#
# **1. Hash1-4xA (i7#10)**
#
#     Number of Evs for incubation with conjugates: 0.5x10^9
#     type of experiment: Hashing
#     Number of emulsion which mixed together:4
#
# **2. Pash1-4xA (i7#11)**
#
#     Number of Evs for incubation with conjugates: 0.5x10^9
#     type of experiment: Pashing
#     Number of emulsion which mixed together:4
#
# **3. Hash2-4xA (i7#12)** (this sample incubated with conjugates for a longer time)
#
#     Number of Evs for incubation with conjugates: 0.5x10^9
#     type of experiment: Hashing
#     Number of emulsion which mixed together:4
#
# **4. Hashing2-2x-B (i7#14)**
#
#     Number of Evs for incubation with conjugates: 0.5x10^9
#     type of experiment: Hashing
#     Number of emulsion which mixed together:2
#
# **5. Hashing2-2x-C (i7#15)**
#
#     Number of Evs for incubation with conjugates: 0.5x10^9
#     type of experiment: Hashing
#     Number of emulsion which mixed together:2
#
#
# **6. Pashing2-2x-D (i7#16)**
#
#     Number of Evs for incubation with conjugates: 0.5x10^9
#     type of experiment:Pashing
#     Number of emulsion which mixed together:2
#
# **7.Pashing2-2x-E (i7#18)**
#
#     Number of Evs for incubation with conjugates: 0.5x10^9
#     type of experiment: Passing
#     Number of emulsion which mixed together:2
#
# Same samples different indexes 4+5 and 6+7

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from tqdm.notebook import tqdm
#import umap
from dbspro.notebook import *

sns.set_context("notebook", font_scale=1.0)
sns.set_style("ticks")

# %% [markdown]
# ## Load data

# %%
abc_target = pd.read_csv("/Users/pontus.hojer/analysis/DBS-Pro_Exosomes/210317_DBS-Pro_P20414/data_processing/abc_target.csv", names=["abc", "target"])
abc_target = {abc.abc: abc.target  for n, abc in abc_target.iterrows()}
targets = list(abc_target.values())

print(abc_target)
# Out:
# {'ABC01': 'EGFR_1', 'ABC03': 'CD9_1', 'ABC06': 'EGFR_2', 'ABC12': 'CD9_2'}

# %%
sample_names= pd.read_csv("/Users/pontus.hojer/analysis/DBS-Pro_Exosomes/211116_DBS-Pro_Hashing_reanalysis/results/samples.tsv", dtype=str, sep="\t")
#sample_names["Path"] = [path / s for s in sample_names["SampleID"].values]

labels = list(sample_names["Sample"])
print(labels)
sample_names
# Out:
# ['Hash1_4xA', 'Pash1_4xA', 'Hash2_4xA', 'Hashing2_2x_B_C', 'Pashing2_2x_D_E']
#             Sample    Reads                                          FastqPath
# 0        Hash1_4xA  1407684  /Users/pontus.hojer/analysis/DBS-Pro_Exosomes/...
# 1        Pash1_4xA  1690871  /Users/pontus.hojer/analysis/DBS-Pro_Exosomes/...
# 2        Hash2_4xA  1810909  /Users/pontus.hojer/analysis/DBS-Pro_Exosomes/...
# 3  Hashing2_2x_B_C  1560185  /Users/pontus.hojer/analysis/DBS-Pro_Exosomes/...
# 4  Pashing2_2x_D_E  2239036  /Users/pontus.hojer/analysis/DBS-Pro_Exosomes/...

# %%
data_raw = pd.read_csv("/Users/pontus.hojer/analysis/DBS-Pro_Exosomes/211116_DBS-Pro_Hashing_reanalysis/results/data.tsv.gz", sep="\t")
data_raw.replace({"Target": abc_target}, inplace=True)
print("Size before:", len(data_raw))
data_raw = data_raw[data_raw["ReadCount"] > 1]
print("Size after:", len(data_raw))
data_raw.head()
# Out:
# Size before: 1979386
# Size after: 661999
#                 Barcode  Target     UMI  ReadCount     Sample
# 0  CAAACAAACAGTGGCACGAT   CD9_1  ATTGGT          5  Hash1_4xA
# 1  CAAACAAACAGTGGCACGAT   CD9_1  TAGGTA          8  Hash1_4xA
# 2  CAAACAAAGGCATGAAGAGC  EGFR_2  AGGGAG          5  Hash1_4xA
# 3  CAAACAAAGGCATGAAGAGC  EGFR_2  AGTGGG          3  Hash1_4xA
# 4  CAAACAAAGGCATGAAGAGC  EGFR_2  TTAGAG          9  Hash1_4xA

# %% [markdown]
# ## Overall QC

# %%
d = data_raw.groupby("Sample", as_index=False).sum()
d["ReadCount"] /= 1_000_000
ax = sns.barplot(data=d, y="Sample", x="ReadCount", order=labels)
_ = ax.set_xlabel("Reads (M)")
_ = ax.set_title("Nr reads per sample")

# %%
d = data_raw.groupby("Sample", as_index=False).count()
d["UMI"] /= 1_000
ax = sns.barplot(data=d, y="Sample", x="UMI", order=labels)
_ = ax.set_xlabel("UMIs (k)")
_ = ax.set_title("Nr UMIs per sample")

# %%
d = data_raw.groupby("Sample").agg({"Barcode":"nunique"})
d /= 1_000

ax = sns.barplot(data=d, y=d.index, x="Barcode", order=labels)
_ = ax.set_xlabel("Barcodes (k)")
_ = ax.set_title("Nr Barcodes per sample")

# %%
d = data_raw.groupby("Sample").agg({"Target":"nunique"})
ax = sns.barplot(data=d, y=d.index, x="Target", order=labels)
_ = ax.set_xlabel("Targets")
_ = ax.set_title("Nr Targets per sample")

# %%
d = data_raw.groupby(["Sample", "Target"], as_index=False).agg({"UMI":"count"})
d["UMI"] /= 1000
g = sns.catplot(data=d, y="Sample", x="UMI",  col="Target", col_wrap=4, kind="bar")
g.fig.subplots_adjust(top=0.85)
_ = g.fig.suptitle("Nr UMIs per Targets")
_ = g.set_axis_labels("UMIs (k)", "")

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.set_title("UMI count distribution")
for label in labels:
    temp = data_raw[data_raw["Sample"] == label].groupby("Barcode", as_index=False)["UMI"].count().sort_values(by="UMI",ascending=False).reset_index(drop=True)
    temp.plot(ax=ax, y="UMI", logx=True, logy=True, label=label)
    
ax.set_xlabel("DBS rank")
ax.set_ylabel("Total UMI count")
#ax.set_xlim(0,100_000)
ax.grid('on', which='major', axis='y', alpha=0.5 )
ax.grid('on', which='major', axis='x',alpha=0.5)
ax.grid('on', which='minor', axis='y', alpha=0.3)
ax.grid('on', which='minor', axis='x', alpha=0.3)
_ = plt.legend(bbox_to_anchor=(1.02, 1), title="Sample", loc='upper left')

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.set_title("Read count distribution")
for label in labels:
    temp = data_raw[data_raw["Sample"] == label].groupby("Barcode", as_index=False)["ReadCount"].sum().sort_values(by="ReadCount",ascending=False).reset_index(drop=True)
    temp.plot(ax=ax, y="ReadCount", logx=True, logy=True, label=label)
    
ax.set_xlabel("DBS rank")
ax.set_ylabel("Total read count")
#ax.set_xlim(0,100_000)
ax.grid('on', which='major', axis='y', alpha=0.5 )
ax.grid('on', which='major', axis='x',alpha=0.5)
ax.grid('on', which='minor', axis='y', alpha=0.3)
ax.grid('on', which='minor', axis='x', alpha=0.3)
_ = plt.legend(bbox_to_anchor=(1.02, 1), title="Sample", loc='upper left')

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_title("Read count per UMI")
for label in labels:
    temp = data_raw[data_raw["Sample"] == label].groupby("UMI", as_index=False)["ReadCount"].sum().sort_values(by="UMI",ascending=False).reset_index(drop=True)
    temp["GC"] = temp["UMI"].apply(lambda x: sum([c in {"G","C"} for c in x])/len(x)) 
    temp["ReadCount"] = temp["ReadCount"]/temp["ReadCount"].sum()
    temp.plot(ax=ax, y="ReadCount", logx=False, logy=False, label=label, alpha=0.3) #, kind="scatter")
    
ax.set_xlabel("UMI (alphabeticaly ranked)")
ax.set_ylabel("% of total reads")
#ax.set_xlim(0,100_000)
ax.grid('on', which='major', axis='y', alpha=0.5 )
ax.grid('on', which='major', axis='x',alpha=0.5)
ax.grid('on', which='minor', axis='y', alpha=0.3)
ax.grid('on', which='minor', axis='x', alpha=0.3)
_ = plt.legend(bbox_to_anchor=(1.02, 1), title="Sample", loc='upper left')

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.set_title("Read count per UMI")
for label in labels:
    temp = data_raw[(data_raw["Sample"] == label) & (data_raw["ReadCount"] > 2)].sort_values(by="ReadCount",ascending=False).reset_index(drop=True)
    #temp["GC"] = temp["UMI"].apply(lambda x: sum([c in {"G","C"} for c in x])/len(x)) 
    temp["ReadCount"] = temp["ReadCount"]/temp["ReadCount"].sum()
    temp.plot(ax=ax, y="ReadCount", logx=False, logy=False, label=label, alpha=1) #, kind="scatter")
    
ax.set_xlabel("UMI (alphabeticaly ranked)")
ax.set_ylabel("% of total reads")
ax.set_yscale("log")
ax.set_xlim(-1000,50_000)
ax.grid('on', which='major', axis='y', alpha=0.5 )
ax.grid('on', which='major', axis='x',alpha=0.5)
ax.grid('on', which='minor', axis='y', alpha=0.3)
ax.grid('on', which='minor', axis='x', alpha=0.3)
_ = plt.legend(bbox_to_anchor=(1.02, 1), title="Sample", loc='upper left')

# %%
temp = data_raw.groupby(["Sample", "UMI"], as_index=False)["ReadCount"].sum().sort_values(by="UMI",ascending=False).reset_index(drop=True).copy()
temp["GC"] = temp["UMI"].apply(lambda x: sum([c in {"G","C"} for c in x])/len(x)).round(2) 
g = sns.catplot(data=temp, x="GC", y="ReadCount", col="Sample", col_wrap=4, height=2, aspect=2, 
                 kind="point", sharey=False, capsize=0.1, estimator=np.median)
g.fig.subplots_adjust(top=0.85)
_ = g.fig.suptitle('GC bias in UMIs')

# %%
temp = data_raw.groupby(["Sample", "Barcode"], as_index=False)["ReadCount"].sum().sort_values(by="Barcode",ascending=False).reset_index(drop=True).copy()
temp["GC"] = temp["Barcode"].apply(lambda x: sum([c in {"G","C"} for c in x])/len(x)).round(2)
g = sns.catplot(data=temp, x="GC", y="ReadCount", col="Sample", height=2, aspect=2, col_wrap=4, 
                kind="point", alpha=0.7, sharey=False, capsize=0.1, estimator=np.median)
g.fig.subplots_adjust(top=0.85)
_ = g.fig.suptitle('GC bias in Barcodes')

# %%
ax = sns.violinplot(data=data_raw.groupby(["Sample","Barcode"], as_index=False)["ReadCount"].sum(), kind="violin", x="Sample", y="ReadCount", bw_adjust=0.1, scale="width")
ax.set_ylim(-5,100)
# Out:
# (-5.0, 100.0)

# %% [markdown]
# ## Initial filtration and generate droplet matrix

# %%
from dbspro.notebook import _filter_wrapper

@_filter_wrapper
def filter_target_count(df: pd.DataFrame, threshold: int, opr=operator.gt) -> pd.DataFrame:
    """Filter UMI count per target"""
    print(f"Filtering for targets with UMI count {opr.__name__} {threshold}")
    return df[opr(df.groupby(["Barcode", "Target"])["UMI"].transform('count'), threshold)]

pd.DataFrame.filter_target_count = filter_target_count

# %%
data_count = []
for l in tqdm(labels):
    print(l)
    data_count.append(
        data_raw[data_raw["Sample"]==l]\
            .filter_rc(1)\
            .filter_uc(1)\
            .filter_ratio(3)\
            .filter_target_count(1)
            .filter_dups(0.5, min_len=2)\
            .to_matrix(qc=True).assign(Sample=l)
    )
    print("")
data_count = pd.concat(data_count)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Hash1_4xA
# Filtering molecules per readcount gt 1
# Barcodes = 28,864 (-0, -0.0%, runtime:0.009354114532470703 s)
# Filtering barcodes by total UMI count gt 1
# Barcodes = 12,330 (-16,534, -57.28%, runtime:0.02597332000732422 s)
# Filtering barcodes by Reads/UMI ratio gt 3
# Barcodes = 8,771 (-3,559, -28.86%, runtime:0.024262189865112305 s)
# Filtering for targets with UMI count gt 1
# Barcodes = 8,028 (-743, -8.47%, runtime:0.013186216354370117 s)
# Filter barcodes whose UMI + Target combos have a jaccard index >0.5
# Parsing pairs:   0%|          | 0.00/32.2M [00:00<?, ?it/s]
# Barcodes = 5,623 (-2,405, -29.96%, runtime:26.191903829574585 s)
#
# Pash1_4xA
# Filtering molecules per readcount gt 1
# Barcodes = 32,287 (-0, -0.0%, runtime:0.011568784713745117 s)
# Filtering barcodes by total UMI count gt 1
# Barcodes = 14,251 (-18,036, -55.86%, runtime:0.03168797492980957 s)
# Filtering barcodes by Reads/UMI ratio gt 3
# ...

# %%
#data_count.to_csv("Hashing_Pashing6.counts.tsv.gz", sep="\t")
data_count = pd.read_csv("Hashing_Pashing6.counts.tsv.gz", sep="\t").set_index("Barcode")

# %%
data_count.head()
# Out:
#                       CD9_1  CD9_2  EGFR_1  EGFR_2     Sample  total_count  \
# Barcode
# CAAACAAACAGTGGCACGAT    2.0    0.0     0.0     0.0  Hash1_4xA            2
# CAAACAAAGGCATGAAGAGC    0.0    0.0     0.0     3.0  Hash1_4xA            3
# CAAACAACGACATAACTTCT    0.0    0.0     0.0     2.0  Hash1_4xA            2
# CAAACAACTAATGGATTTAT    0.0    0.0     2.0     0.0  Hash1_4xA            2
# CAAACACCTTATGAGTTTAT    2.0    0.0     0.0     0.0  Hash1_4xA            2
#
#                       nr_targets  total_reads
# Barcode
# CAAACAAACAGTGGCACGAT           1           13
# CAAACAAAGGCATGAAGAGC           1           17
# CAAACAACGACATAACTTCT           1           14
# CAAACAACTAATGGATTTAT           1           23
# CAAACACCTTATGAGTTTAT           1           37

# %% [markdown]
# ## Per Droplet QC

# %%
bins = np.array(range(1,6))

g = sns.displot(data_count, x="nr_targets", col="Sample", col_wrap=4, bins=bins, 
                height=2, aspect=2, facet_kws={'sharey': True})
g.fig.subplots_adjust(top=0.9)
_ = g.fig.suptitle("Nr Targets")
g.set(yscale="log", xticks = bins[:-1] + 0.5, xticklabels=bins[:-1])
g.set_titles("{col_name}")

# %%
ax = sns.violinplot(data=data_count, y="total_reads", x="Sample", scale="width", cut=0.5)
ax = sns.stripplot(data=data_count, y="total_reads", x="Sample", size=2, jitter=0.45, color="black", alpha=0.1)
ax.set_ylim(0,120)
#ax.set_yscale("log")
# Out:
# (0.0, 120.0)

# %%
ax = sns.violinplot(data=data_count, y="total_count", x="Sample", bw=0.5, scale="width", cut=0.5)
ax = sns.stripplot(data=data_count, y="total_count", x="Sample", size=1, jitter=0.45, color="black", alpha=0.2)

#ax.set_yscale("log")
ax.set_ylim(0,20)
# Out:
# (0.0, 20.0)

# %%
import matplotlib.ticker as tkr
d = data_count.copy()
d["log2_total_reads"] = np.log2(d["total_reads"])
g = sns.displot(d, x="log2_total_reads", col="Sample", col_wrap=3, bins=40,
                height=2, aspect=3, facet_kws={'sharey': False})
g.fig.subplots_adjust(top=0.87)
_ = g.fig.suptitle("Nr of reads total")
g.set(yscale="log", )
g.set_titles("{col_name}")
for ax in g.axes.flat:
    ax.xaxis.set_major_formatter(tkr.FuncFormatter(lambda x, p: str(int(2**x))))

# %%
import matplotlib.ticker as tkr
d = data_count.copy()
d["log2_total_count"] = np.log2(d["total_count"])
g = sns.displot(d, x="log2_total_count", col="Sample", col_wrap=3, bins=40,
                height=2, aspect=3, facet_kws={'sharey': False})
g.fig.subplots_adjust(top=0.87)
_ = g.fig.suptitle("Nr of UMIs total")
g.set(yscale="log", )
g.set_titles("{col_name}")
for ax in g.axes.flat:
    ax.xaxis.set_major_formatter(tkr.FuncFormatter(lambda x, p: str(int(2**x))))

# %%
d = [] 
for group, data in data_count.groupby("Sample", as_index=False):
    data["rank"] = data["total_reads"].rank(ascending=False)
    data["rel_rank"] = data["rank"] / data["rank"].max()
    d.append(data)
    
d = pd.concat(d)
ax = sns.lineplot(data=d, y="total_reads", x="rank", hue="Sample")
ax.set_xscale("log")

ax.set_yscale("log")

# %%
d = [] 
for group, data in data_count.groupby("Sample", as_index=False):
    data["rank"] = data["total_count"].rank(ascending=False)
    data["rel_rank"] = data["rank"] / data["rank"].max()
    d.append(data)
    
d = pd.concat(d)
ax = sns.lineplot(data=d, y="total_count", x="rank", hue="Sample")
ax.set_xscale("log")

ax.set_yscale("log")

# %% [markdown]
# ## Filter data further

# %%
# Only keep droplets with CD9 and EGFR from either Set1 and/or Set2.
#data_filt = data_count.groupby("dataset", as_index=False).apply(lambda x: x[(((x["CD9_1"] > 0) & (x["EGFR_1"] > 0)) | ((x["CD9_2"] > 0)) & (x["EGFR_2"] > 0))])

# Only keep droplets with two or more UMIs from either Set1 and/or Set2.
#data_filt = data_count.groupby("dataset", as_index=False).apply(lambda x: x[((x["CD9_1"] + x["EGFR_1"] > 1) | (x["CD9_2"] + x["EGFR_2"] > 1)) ])

# Only keep droplets with EGFR and CD9
#data_filt = data_count.groupby("dataset", as_index=False).apply(lambda x: x[((x["CD9_1"] + x["CD9_2"]) > 0) & ((x["EGFR_1"] + x["EGFR_2"]) > 0)])
data_filt = data_count.copy()
# Filter on UMI count
#data_filt = data_filt.groupby("dataset", as_index=False).apply(lambda x: x[x["total_count"] < 16])
data_filt = data_filt[(data_filt["total_count"] < 15)]
#data_filt = data_filt[(data_filt["total_count"] > 3)]


# Filter on reads count
#data_filt = data_filt.groupby("dataset", as_index=False).apply(lambda x: x[x["total_reads"] < 50])

# %%
data_filt.groupby("Sample").count()["total_count"]
# Out:
# Sample
# Hash1_4xA           5591
# Hash2_4xA          14557
# Hashing2_2x_B_C     9227
# Pash1_4xA           5220
# Pashing2_2x_D_E    11924
# Name: total_count, dtype: int64

# %%
sns.set_theme(style="white", palette=None)

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
d = data_filt.copy()
d["Set1"] = ((d["CD9_1"]>0) & (d["EGFR_1"]>0)).astype(int)
d["Set2"] = ((d["CD9_2"]>0) & (d["EGFR_2"]>0)).astype(int)
d["Both"] = ((d["Set1"]>0) & (d["Set2"]>0)).astype(int)
d["Any"] = ((d["Set1"]>0) | (d["Set2"]>0)).astype(int)
d["OnlySet1"] = ((d["Set1"]>0) & (d["Set2"]==0)).astype(int)
d["OnlySet2"] = ((d["Set1"]==0) & (d["Set2"]>0)).astype(int)
s = d.groupby("Sample").sum().drop(targets + ["nr_targets"], axis=1)
s["Mixed"] = 100 * s["Both"] / s["Any"]
s["Single"] = 100 - s["Mixed"]
display(s)
ax1 = s[["Single", "Mixed"]].plot(kind="bar", stacked=True, edgecolor="black", color=["black", "red"], ax=ax1)
ax1.set_title("CD9 and EGFR from same set")
ax1.set_ylabel("% of droplets")

d = data_filt.copy()
d["Set1"] = ((d["CD9_1"]>0) & (d["EGFR_2"]>0)).astype(int)
d["Set2"] = ((d["CD9_2"]>0) & (d["EGFR_1"]>0)).astype(int)
d["Both"] = ((d["Set1"]>0) & (d["Set2"]>0)).astype(int)
d["Any"] = ((d["Set1"]>0) | (d["Set2"]>0)).astype(int)
d["OnlySet1"] = ((d["Set1"]>0) & (d["Set2"]==0)).astype(int)
d["OnlySet2"] = ((d["Set1"]==0) & (d["Set2"]>0)).astype(int)
s = d.groupby("Sample").sum().drop(targets + ["nr_targets"], axis=1)
s["Mixed"] = 100 * s["Both"] / s["Any"]
s["Single"] = 100 - s["Mixed"]
display(s)
ax2 = s[["Single", "Mixed"]].plot(kind="bar", stacked=True, edgecolor="black", color=["black", "red"], ax=ax2)
ax2.set_title("CD9 and EGFR from same set (FLIPPED)")
ax2.set_ylabel("% of droplets")


#_ = plt.legend(bbox_to_anchor=(1.02, 1), title="Type", loc='upper left')
plt.tight_layout()
#for ext in ["png", "svg"]:
#    plt.savefig(f"images/211101_Hashing_Pashing_mixing.CD9_and_EGFR_same_set.{ext}", dpi=300)
# Out:
#                  total_count  total_reads  Set1  Set2  Both  Any  OnlySet1  \
# Sample
# Hash1_4xA              14747       193212    61    79     1  139        60
# Hash2_4xA              35449       226669   137   196     1  332       136
# Hashing2_2x_B_C        22767       168014    95   136     4  227        91
# Pash1_4xA              13713       177596    61    61     0  122        61
# Pashing2_2x_D_E        30738       253243   130   198     5  323       125
#
#                  OnlySet2     Mixed      Single
# Sample
# Hash1_4xA              78  0.719424   99.280576
# Hash2_4xA             195  0.301205   99.698795
# Hashing2_2x_B_C       132  1.762115   98.237885
# Pash1_4xA              61  0.000000  100.000000
# Pashing2_2x_D_E       193  1.547988   98.452012
#                  total_count  total_reads  Set1  Set2  Both  Any  OnlySet1  \
# Sample
# Hash1_4xA              14747       193212    10    18     1   27         9
# ...

# %%
d = data_filt.copy()
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
d["Set1"] = ((d["CD9_1"]>0) | (d["EGFR_1"]>0)).astype(int)
d["Set2"] = ((d["CD9_2"]>0) | (d["EGFR_2"]>0)).astype(int)
d["Both"] = ((d["Set1"]>0) & (d["Set2"]>0)).astype(int)
d["Any"] = ((d["Set1"]>0) | (d["Set2"]>0)).astype(int)
d["OnlySet1"] = ((d["Set1"]>0) & (d["Set2"]==0)).astype(int)
d["OnlySet2"] = ((d["Set1"]==0) & (d["Set2"]>0)).astype(int)
s = d.groupby("Sample").sum().drop(targets + ["nr_targets"], axis=1)
s["Mixed"] = 100 * s["Both"] / s["Any"] 
s["Single"] = 100 - s["Mixed"]
display(s)
ax1 = s[["Single", "Mixed"]].plot(kind="bar", stacked=True, edgecolor="black", color=["black", "red"], ax=ax1)
ax1.set_title("CD9 or EGFR from same set")
ax1.set_ylabel("% of droplets")

d = data_filt.copy()
d["Set1"] = ((d["CD9_1"]>0) | (d["EGFR_2"]>0)).astype(int)
d["Set2"] = ((d["CD9_2"]>0) | (d["EGFR_1"]>0)).astype(int)
d["Both"] = ((d["Set1"]>0) & (d["Set2"]>0)).astype(int)
d["Any"] = ((d["Set1"]>0) | (d["Set2"]>0)).astype(int)
d["OnlySet1"] = ((d["Set1"]>0) & (d["Set2"]==0)).astype(int)
d["OnlySet2"] = ((d["Set1"]==0) & (d["Set2"]>0)).astype(int)
s = d.groupby("Sample").sum().drop(targets + ["nr_targets"], axis=1)
s["Mixed"] = 100 * s["Both"] / s["Any"] 
s["Single"] = 100 - s["Mixed"]
display(s)
ax2 = s[["Single", "Mixed"]].plot(kind="bar", stacked=True, edgecolor="black", color=["black", "red"], ax=ax2)
ax2.set_title("CD9 or EGFR from same set (FLIPPED)")
ax2.set_ylabel("% of droplets")

plt.tight_layout()
#for ext in ["png", "svg"]:
#    plt.savefig(f"images/211101_Hashing_Pashing_mixing.CD9_or_EGFR_same_set.{ext}", dpi=300)
# Out:
#                  total_count  total_reads  Set1  Set2  Both    Any  OnlySet1  \
# Sample
# Hash1_4xA              14747       193212  2727  2935    71   5591      2656
# Hash2_4xA              35449       226669  6641  8098   182  14557      6459
# Hashing2_2x_B_C        22767       168014  4060  5289   122   9227      3938
# Pash1_4xA              13713       177596  2594  2685    59   5220      2535
# Pashing2_2x_D_E        30738       253243  4938  7160   174  11924      4764
#
#                  OnlySet2     Mixed     Single
# Sample
# Hash1_4xA            2864  1.269898  98.730102
# Hash2_4xA            7916  1.250258  98.749742
# Hashing2_2x_B_C      5167  1.322207  98.677793
# Pash1_4xA            2626  1.130268  98.869732
# Pashing2_2x_D_E      6986  1.459242  98.540758
#                  total_count  total_reads  Set1  Set2  Both    Any  OnlySet1  \
# Sample
# Hash1_4xA              14747       193212  2760  3014   183   5591      2577
# ...

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
d = data_filt.copy()
d["Set1"] = ((d["CD9_1"] + d["EGFR_1"])>1).astype(int)
d["Set2"] = ((d["CD9_2"] + d["EGFR_2"])>1).astype(int)
d["Both"] = ((d["Set1"]>0) & (d["Set2"]>0)).astype(int)
d["Any"]  = ((d["Set1"]>0) | (d["Set2"]>0)).astype(int)
d["Neither"]  = ((d["Set1"]==0) & (d["Set2"]==0)).astype(int)
d["OnlySet1"] = ((d["Set1"]>0) & (d["Set2"]==0)).astype(int)
d["OnlySet2"] = ((d["Set1"]==0) & (d["Set2"]>0)).astype(int)
s = d.groupby("Sample").sum().drop(targets + ["nr_targets"], axis=1)
s["Mixed"] = 100 * s["Both"] / s["Any"] 
s["Single"] = 100 - s["Mixed"]
display(s)

ax1 = s[["Single", "Mixed"]].plot(kind="bar", stacked=True, edgecolor="black", color=["black", "red"], ax=ax1)
ax1.set_title(">1 CD9 or EGFR from same set")
ax1.set_ylabel("% of droplets")

d = data_filt.copy()
d["Set1"] = ((d["CD9_1"] + d["EGFR_2"])>1).astype(int)
d["Set2"] = ((d["CD9_2"] + d["EGFR_1"])>1).astype(int)
d["Both"] = ((d["Set1"]>0) & (d["Set2"]>0)).astype(int)
d["Any"]  = ((d["Set1"]>0) | (d["Set2"]>0)).astype(int)
d["Neither"]  = ((d["Set1"]==0) & (d["Set2"]==0)).astype(int)
d["OnlySet1"] = ((d["Set1"]>0) & (d["Set2"]==0)).astype(int)
d["OnlySet2"] = ((d["Set1"]==0) & (d["Set2"]>0)).astype(int)
s = d.groupby("Sample").sum().drop(targets + ["nr_targets"], axis=1)
s["Mixed"] = 100 * s["Both"] / s["Any"] 
s["Single"] = 100 - s["Mixed"]
display(s)

ax2 = s[["Single", "Mixed"]].plot(kind="bar", stacked=True, edgecolor="black", color=["black", "red"], ax=ax2)
ax2.set_title(">1 CD9 or EGFR from same set (FLIPPED)")
ax2.set_ylabel("% of droplets")
plt.tight_layout()
#for ext in ["png", "svg"]:
#    plt.savefig(f"images/211101_Hashing_Pashing_mixing.more_than_one_CD9_or_EGFR_from_same_set.{ext}", dpi=300)
# Out:
#                  total_count  total_reads  Set1  Set2  Both    Any  Neither  \
# Sample
# Hash1_4xA              14747       193212  2727  2935    71   5591        0
# Hash2_4xA              35449       226669  6641  8098   182  14557        0
# Hashing2_2x_B_C        22767       168014  4060  5289   122   9227        0
# Pash1_4xA              13713       177596  2594  2685    59   5220        0
# Pashing2_2x_D_E        30738       253243  4938  7160   174  11924        0
#
#                  OnlySet1  OnlySet2     Mixed     Single
# Sample
# Hash1_4xA            2656      2864  1.269898  98.730102
# Hash2_4xA            6459      7916  1.250258  98.749742
# Hashing2_2x_B_C      3938      5167  1.322207  98.677793
# Pash1_4xA            2535      2626  1.130268  98.869732
# Pashing2_2x_D_E      4764      6986  1.459242  98.540758
#                  total_count  total_reads  Set1  Set2  Both    Any  Neither  \
# Sample
# ...

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
d = data_filt.copy()
threshold = 0.8
d["OnlySet1"] = ((d["CD9_1"] + d["EGFR_1"]) > (threshold * d["total_count"])).astype(int)
d["OnlySet2"] = ((d["CD9_2"] + d["EGFR_2"]) > (threshold * d["total_count"])).astype(int)
d["Both"] = ((d["OnlySet1"]==0) & (d["OnlySet2"]==0)).astype(int)
d["Any"]  = 1
s = d.groupby("Sample").sum().drop(targets + ["nr_targets"], axis=1)
s["Mixed"] = 100 * s["Both"] / s["Any"] 
s["Single"] = 100 - s["Mixed"]
display(s)

ax1 = s[["Single", "Mixed"]].plot(kind="bar", stacked=True, edgecolor="black", color=["black", "red"], ax=ax1)
ax1.set_title(f"{threshold:.0%} of UMIs from same set")
ax1.set_ylabel("% of droplets")

d = data_filt.copy()
threshold = 0.8
d["OnlySet1"] = ((d["CD9_1"] + d["EGFR_2"]) > (threshold * d["total_count"])).astype(int)
d["OnlySet2"] = ((d["CD9_2"] + d["EGFR_1"]) > (threshold * d["total_count"])).astype(int)
d["Both"] = ((d["OnlySet1"]==0) & (d["OnlySet2"]==0)).astype(int)
d["Any"]  = 1
s = d.groupby("Sample").sum().drop(targets + ["nr_targets"], axis=1)
s["Mixed"] = 100 * s["Both"] / s["Any"] 
s["Single"] = 100 - s["Mixed"]
display(s)

ax2 = s[["Single", "Mixed"]].plot(kind="bar", stacked=True, edgecolor="black", color=["black", "red"], ax=ax2)
ax2.set_title(f"{threshold:.0%} of UMIs from same set (FILPPED)")
ax2.set_ylabel("% of droplets")

plt.tight_layout()
#for ext in ["png", "svg"]:
#    plt.savefig(f"images/211101_Hashing_Pashing_mixing.{threshold:.0%}_UMIs_from_same_set.{ext}", dpi=300)
# Out:
#                  total_count  total_reads  OnlySet1  OnlySet2  Both    Any  \
# Sample
# Hash1_4xA              14747       193212      2656      2864    71   5591
# Hash2_4xA              35449       226669      6460      7916   181  14557
# Hashing2_2x_B_C        22767       168014      3939      5167   121   9227
# Pash1_4xA              13713       177596      2535      2626    59   5220
# Pashing2_2x_D_E        30738       253243      4766      6990   168  11924
#
#                     Mixed     Single
# Sample
# Hash1_4xA        1.269898  98.730102
# Hash2_4xA        1.243388  98.756612
# Hashing2_2x_B_C  1.311369  98.688631
# Pash1_4xA        1.130268  98.869732
# Pashing2_2x_D_E  1.408923  98.591077
#                  total_count  total_reads  OnlySet1  OnlySet2  Both    Any  \
# Sample
# Hash1_4xA              14747       193212      2578      2831   182   5591
# Hash2_4xA              35449       226669      6597      7524   436  14557
# ...

# %%
d = data_count.copy()
#d = d[(d["total_count"] < 50) & (d["total_count"] > 1)]
d["Set1"] = d["CD9_1"] + d["EGFR_1"]
d["Set2"] = d["CD9_2"] + d["EGFR_2"]
s = d.groupby(["Sample", "Set1", "Set2"], as_index=False)["total_count"].count()
s["total"] = s["Set1"] + s["Set2"]
s["norm_count"] = s.groupby(["Sample","total"], as_index=False)["total_count"].transform(lambda x: 100 * x / x.sum())
s["log10_count"] = np.log10(s["total_count"]).round(1)
s["log2_count"] = np.log2(s["total_count"]).round(1)
s["mixed"] = (((s["Set1"] / s["total"]) < 0.80) & ((s["Set2"] / s["total"]) < 0.80))
s["mixed_count"] = s["mixed"].astype(int)*s["total_count"]

mix_rates = s.groupby(["Sample"])[["total_count", "mixed_count"]].sum()
mix_rates["rate"] = 100 * mix_rates["mixed_count"] / mix_rates["total_count"]
display(mix_rates)

g = sns.relplot(data=s, x="Set1", y="Set2", size="log10_count", hue="mixed", col="Sample", sizes=(10,200), palette=["black", "red"], col_wrap=3)
g.set(xlabel="CD9_1 + EGFR_1", ylabel="CD9_2 + EGFR_2", ylim=(-1,30), xlim=(-1,30))
# Out:
#                  total_count  mixed_count      rate
# Sample
# Hash1_4xA               5623           98  1.742842
# Hash2_4xA              14557          180  1.236519
# Hashing2_2x_B_C         9232          124  1.343154
# Pash1_4xA               5270          104  1.973435
# Pashing2_2x_D_E        11928          171  1.433602

# %%
data_count2 = []
for l in tqdm(labels):
    print(l)
    data_count2.append(
        data_raw[data_raw["Sample"]==l]\
            .filter_uc(1)\
            .filter_ratio(3)\
#            .filter_target_count(1)\
            .to_matrix(qc=True).assign(Sample=l)
    )
    print("")
data_count2 = pd.concat(data_count2)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Hash1_4xA
# Filtering barcodes by total UMI count gt 1
# Barcodes = 12,330 (-16,534, -57.28%, runtime:0.0274960994720459 s)
# Filtering barcodes by Reads/UMI ratio gt 3
# Barcodes = 8,771 (-3,559, -28.86%, runtime:0.025462865829467773 s)
#
# Pash1_4xA
# Filtering barcodes by total UMI count gt 1
# Barcodes = 14,251 (-18,036, -55.86%, runtime:0.033435821533203125 s)
# Filtering barcodes by Reads/UMI ratio gt 3
# Barcodes = 8,538 (-5,713, -40.09%, runtime:0.029497146606445312 s)
#
# Hash2_4xA
# Filtering barcodes by total UMI count gt 1
# Barcodes = 40,488 (-68,881, -62.98%, runtime:0.0844111442565918 s)
# Filtering barcodes by Reads/UMI ratio gt 3
# Barcodes = 28,787 (-11,701, -28.9%, runtime:0.06840085983276367 s)
#
# Hashing2_2x_B_C
# Filtering barcodes by total UMI count gt 1
# Barcodes = 27,939 (-39,763, -58.73%, runtime:0.0516049861907959 s)
# Filtering barcodes by Reads/UMI ratio gt 3
# ...

# %%
d = data_count2.copy()
d = d[d["total_count"] < 20]
#d = d[d["total_count"] > 2]
d["Set1"] = d["CD9_1"] + d["EGFR_1"]
d["Set2"] = d["CD9_2"] + d["EGFR_2"]
s = d.groupby(["Sample", "Set1", "Set2"], as_index=False)["total_count"].count()
s["total"] = s["Set1"] + s["Set2"]
s["norm_count"] = s.groupby(["Sample","total"], as_index=False)["total_count"].transform(lambda x: 100 * x / x.sum())
s["log10_count"] = np.log10(s["total_count"]).round(1)
s["log2_count"] = np.log2(s["total_count"]).round(1)
s["mixed"] = (((s["Set1"] / s["total"]) < 0.80) & ((s["Set2"] / s["total"]) < 0.80))
s["mixed_count"] = s["mixed"].astype(int)*s["total_count"]

mix_rates = s.groupby(["Sample"])[["total_count", "mixed_count"]].sum()
mix_rates["rate"] = 100 * mix_rates["mixed_count"] / mix_rates["total_count"]
display(mix_rates)

g = sns.relplot(data=s, x="Set1", y="Set2", size="log10_count", hue="mixed", col="Sample", sizes=(10, 200), palette=["black", "red"])
g.set(xlabel="CD9_1 + EGFR_1", ylabel="CD9_2 + EGFR_2")#, ylim=(-1,30), xlim=(-1,30))
# Out:
# Target           total_count  mixed_count      rate
# Sample
# Hash1_4xA               7808          635  8.132684
# Hash2_4xA              25455         1008  3.959929
# Hashing2_2x_B_C        15147         1299  8.575956
# Pash1_4xA               7606          603  7.927952
# Pashing2_2x_D_E        22303         1434  6.429628

# %%
d = data_filt.copy()
d["Set1"] = d["CD9_1"] + d["EGFR_1"]
d["Set2"] = d["CD9_2"] + d["EGFR_2"]
d["Lean1"] = 100 * d["Set1"] / (d["Set1"]+d["Set2"])
d["Lean2"] = 100 * d["Set2"] / (d["Set1"]+d["Set2"])
d=d.sort_values(by="Sample")
ax = sns.violinplot(data=d, y="Sample", bw=0.1, x="Lean1", width=1, scale="count", inner=None)
#ax = sns.stripplot(data=d, y="dataset", x="Lean1", color="k", jitter=0.4, ax=ax, size=2)
_ = ax.set_ylabel("")
_ = ax.set_xlabel("% belonging to Set1")

plt.tight_layout()
#for ext in ["png", "svg"]:
#    plt.savefig(f"images/211001_Hashing_Pashing_violinplots.{ext}", dpi=300)

# %%
# Initialize the FacetGrid object
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0), 'axes.linewidth':2})
pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
g = sns.FacetGrid(d, row="dataset", hue="dataset", aspect=15, height=.5, palette=pal)

# Draw the densities in a few steps
g.map(sns.kdeplot, "Lean1", bw_adjust=0.5, clip_on=False, fill=True, alpha=1, lw=1.5)
g.map(sns.kdeplot, "Lean1", bw_adjust=0.5, clip_on=False, color="w", alpha=0.8, lw=2)

# passing color=None to refline() uses the hue mapping
#g.map(plt.axhline, y=0, lw=2, clip_on=False)

# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0.95, 0.2, label, fontweight="bold", color="k",
            ha="left", va="center", transform=ax.transAxes)
    
g.map(label, "Lean1")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.45)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
_ = g.despine(bottom=True, left=True)
# Out:
# /Users/pontus.hojer/miniconda3/envs/dbspro/lib/python3.6/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)
# /Users/pontus.hojer/miniconda3/envs/dbspro/lib/python3.6/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)

# %%
threshold = 80

d["Mixed"] = ((d["Lean1"]<threshold) & (d["Lean2"]<threshold)).astype(int)
d.groupby("dataset").apply(lambda x: sum(x["Mixed"])/len(x))
# Out:
# dataset
# Hash1-4xA        0.245819
# Hashing2-2x-B    0.226667
# Hashing2-2x-C    0.235294
# Pash1-4xA        0.181053
# Pashing2-2x-D    0.093923
# Pashing2-2x-E    0.211382
# dtype: float64

# %%
#d = data_count[(data_count["total_count"] < 10) & (data_count["total_reads"] < 40) & (data_count["total_reads"] > 5)].copy()
#d = data_count[data_count["total_count"] < 9].copy()
d = data_filt.copy()
d["Set1"] = d["CD9_1"] + d["EGFR_1"]
d["Set2"] = d["CD9_2"] + d["EGFR_2"]
d["Lean1"] = 100 * d["Set1"] / (d["Set1"]+d["Set2"])
d["Lean2"] = 100 * d["Set2"] / (d["Set1"]+d["Set2"])
d["Mixed"] = ((d["Lean1"]<threshold*100) & (d["Lean2"]<threshold*100)).astype(int)
display(d.groupby("Sample").apply(lambda x: x["Mixed"].sum()/len(x)))
display(d.groupby(["Sample","total_count"]).apply(lambda x: x["Mixed"].sum()/len(x)))
g = sns.catplot(data=d, y="total_count", x="Lean1", col="Sample", kind="violin", scale="width", orient="h",
                cut=0.5, bw=0.2, inner=None, aspect=0.4, col_wrap=6)
# Out:
# Sample
# Hash1_4xA          0.079906
# Hash2_4xA          0.117070
# Hashing2_2x_B_C    0.118247
# Pash1_4xA          0.071240
# Pashing2_2x_D_E    0.100496
# dtype: float64
# Sample           total_count
# Hash1_4xA        4              0.068650
#                  5              0.064356
#                  6              0.079545
#                  7              0.153846
#                  8              0.111111
#                  9              0.185185
#                  10             0.181818
#                  11             0.000000
# Hash2_4xA        4              0.085379
#                  5              0.105413
#                  6              0.188406
#                  7              0.250000
#                  8              0.400000
#                  9              0.571429
#                  10             0.400000
#                  11             0.500000
# Hashing2_2x_B_C  4              0.063551
#                  5              0.088106
# ...

# %%
g = sns.displot(
    data=d, x="Lean1", hue="total_count", col="Sample", common_norm=False, alpha=0.7, fill=True,
    kind="kde", height=4, aspect=.7, clip=(-10,110), bw_adjust=0.4, multiple="layer",
)
g.set_titles("{col_name}")

# %%
#d = data_count[(data_count["total_count"] < 10) & (data_count["total_reads"] < 40) & (data_count["total_reads"] > 5)].copy()
d = data_count[data_count["total_count"] < 20].copy()
d["Set1"] = d["CD9_1"] + d["EGFR_1"]
d["Set2"] = d["CD9_2"] + d["EGFR_2"]
d["Lean1"] = 100 * d["Set1"] / (d["Set1"]+d["Set2"])
d["Lean2"] = 100 * d["Set2"] / (d["Set1"]+d["Set2"])
g = sns.catplot(data=d, y="total_count", x="Lean1", col="dataset", kind="violin", scale="width", orient="h",
                cut=0.5, bw=0.1, inner=None, aspect=0.4, col_wrap=6)

# %%
#d = data_count[(data_count["total_count"] < 10) & (data_count["total_reads"] < 40) & (data_count["total_reads"] > 5)].copy()
d = data_count[data_count["total_count"] < 10].copy()
d["Set1"] = d["CD9_1"] + d["EGFR_1"]
d["Set2"] = d["CD9_2"] + d["EGFR_2"]
d["Lean1"] = 100 * d["Set1"] / (d["Set1"]+d["Set2"])
d["Lean2"] = 100 * d["Set2"] / (d["Set1"]+d["Set2"])
g = sns.catplot(data=d, y="total_count", x="Lean1", col="dataset", kind="strip", jitter=0.45, orient="h",
                aspect=0.4, col_wrap=6, alpha=0.01)

# %%
#d = data_count[data_count["total_reads"] < 80].copy()
d = data_filt[data_filt["total_reads"] < 100].copy()
d["read_bin"] = pd.cut(d["total_reads"], 20)
d["Set1"] = d["CD9_1"] + d["EGFR_1"]
d["Set2"] = d["CD9_2"] + d["EGFR_2"]
d["Lean1"] = 100 * d["Set1"] / (d["Set1"]+d["Set2"])
d["Lean2"] = 100 * d["Set2"] / (d["Set1"]+d["Set2"])
g = sns.catplot(data=d, y="read_bin", x="Lean1", col="dataset", kind="violin", scale="width", orient="h",
                cut=0.5, bw=0.2, inner=None, aspect=0.4)

# %% [markdown]
# ## Correlation

# %%
fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(14,8))
for l, ax in zip(labels, axes.ravel()):
    print(l)
    d = data_filt[(data_filt["Sample"] == l)].loc[:, targets].copy()
    #d = data_count[(data_count["dataset"] == l)].copy()
    #d = data_raw[data_raw["dataset"] == l].filter_rc(4).to_matrix()
    #d = d[d["total_count"] > 2]
    d = d.loc[:, targets].apply(np.log1p)
    d = clr_normalize(d.loc[:, targets], on_cells=False)
    corr = d.corr(method="pearson")
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    sns.heatmap(data=corr, annot=True, ax=ax, label=l, mask=mask, square=True, vmax=0.5, vmin=-0.5)
    ax.set_title(l)
    
    #plt.show()
plt.tight_layout()
# Out:
# Hash1_4xA
# Pash1_4xA
# Hash2_4xA
# Hashing2_2x_B_C
# Pashing2_2x_D_E

# %%
d = data_filt.copy()
combos=[]

for ts in combinations(targets, 2):
    combo = " & ".join(ts)
    combos.append(combo)
    ts_list = list(ts)
    t = ts_list.pop()
    temp = (d[t] > 0)
    while ts_list:
        t = ts_list.pop()
        temp = np.logical_and(temp, (d[t] > 0))

    d[combo] = temp.astype(int) 

d = d.loc[:,combos+ ["Sample"]]
d = d.groupby("Sample").apply(lambda x: 100 * x.sum() / x.count())
#d = d.div(d.max(axis=1), axis=0)
print(d.head())
maxd = d.mean()#agg(lambda x: x.std()/x.mean()).copy()
maxd.name = "max"
d = d.append(maxd)
d = d.sort_values(by="max", axis=1, ascending=False)
d = d.iloc[:5,:]
grid_kws = {"height_ratios": (.03, .6), "hspace": .2}
f, (cbar_ax, ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(10,4))
ax = sns.heatmap(data=d, ax=ax, cbar_ax=cbar_ax, 
                 cbar_kws={"orientation": "horizontal", "label":"% of barcodes"},
                 square=True, vmin=0, annot=True, fmt='.1f',
                 linewidths=.5, cmap="Reds", xticklabels=1,
                 annot_kws={"fontsize":10})
_ = plt.xlabel("Target combinations")
_ = plt.ylabel("")
# Out:
# Target           EGFR_1 & CD9_1  EGFR_1 & EGFR_2  EGFR_1 & CD9_2  \
# Sample
# Hash1_4xA              7.050529         0.352526        1.997650
# Hash2_4xA              8.894702         1.046436        1.896664
# Hashing2_2x_B_C        9.480122         1.732926        3.363914
# Pash1_4xA              7.783641         0.263852        0.923483
# Pashing2_2x_D_E        7.878412         1.488834        2.977667
#
# Target           CD9_1 & EGFR_2  CD9_1 & CD9_2  EGFR_2 & CD9_2
# Sample
# Hash1_4xA              1.057579       5.640423        8.695652
# Hash2_4xA              3.073905       7.586658       12.818836
# Hashing2_2x_B_C        4.281346       6.931702       13.557594
# Pash1_4xA              1.055409       5.540897        7.651715
# Pashing2_2x_D_E        1.985112       5.707196       11.786600

# %%
d.div(d.max(axis=1), axis=0)
# Out:
# Target           EGFR_2 & CD9_2  EGFR_1 & CD9_1  CD9_1 & CD9_2  \
# Sample
# Hash1_4xA              1.000000        0.810811       0.648649
# Hash2_4xA              1.000000        0.693878       0.591837
# Hashing2_2x_B_C        1.000000        0.699248       0.511278
# Pash1_4xA              0.983051        1.000000       0.711864
# Pashing2_2x_D_E        1.000000        0.668421       0.484211
#
# Target           CD9_1 & EGFR_2  EGFR_1 & CD9_2  EGFR_1 & EGFR_2
# Sample
# Hash1_4xA              0.121622        0.229730         0.040541
# Hash2_4xA              0.239796        0.147959         0.081633
# Hashing2_2x_B_C        0.315789        0.248120         0.127820
# Pash1_4xA              0.135593        0.118644         0.033898
# Pashing2_2x_D_E        0.168421        0.252632         0.126316

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

data_norm = data_filt.copy() 
data_norm["mix"] = abs(((data_norm["CD9_1"] + data_norm["EGFR_1"]) / data_norm["total_count"]) - 0.5) / 0.5
data_norm.loc[:, targets] = data_norm.loc[:, targets].apply(np.log1p)
#data_norm.loc[:, targets] = StandardScaler().fit_transform(data_norm.loc[:, targets])
pca = PCA(n_components=4).fit(data_norm.loc[:,targets])
pca_comps = pca.transform(data_norm.loc[:,targets])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.45581658, 0.28317924, 0.23169939, 0.02930478])

# %%
pca.n_features_in_
# Out:
# 4

# %%
d = data_norm.copy()
for i in range(4):
    d[f"PCA{i+1}"] = pca_comps[:, i]
d.head()
# Out:
# Target                   CD9_1     CD9_2  EGFR_1    EGFR_2     Sample  \
# Barcode
# CAAACTCTTGAAGAGACGGC  0.000000  0.000000     0.0  1.609438  Hash1_4xA
# CAAATAATCTAATTGAGTGA  1.609438  0.000000     0.0  0.000000  Hash1_4xA
# CAAATACTTACTTAATTTCA  0.000000  1.386294     0.0  1.098612  Hash1_4xA
# CAAATAGTCTCACAAATAGT  0.000000  0.000000     0.0  2.302585  Hash1_4xA
# CAAATGATGTACGTCTCTAC  1.609438  0.000000     0.0  0.000000  Hash1_4xA
#
# Target                total_count  nr_targets  total_reads  mix      PCA1  \
# Barcode
# CAAACTCTTGAAGAGACGGC            4           1           23  1.0  0.227942
# CAAATAATCTAATTGAGTGA            4           1          388  1.0  1.105975
# CAAATACTTACTTAATTTCA            5           2           16  1.0 -0.856554
# CAAATAGTCTCACAAATAGT            9           1           36  1.0  0.204139
# CAAATGATGTACGTCTCTAC            4           1           36  1.0  1.105975
#
# Target                    PCA2      PCA3      PCA4
# Barcode
# ...

# %%
sns.relplot(data=d, x="PCA1", y="PCA2", kind="scatter", col="Sample", hue="mix", size=1, alpha=1)

# %%
sns.relplot(data=d, x="PCA2", y="PCA3", kind="scatter", col="Sample", hue="mix", size=1, alpha=1)

# %%
sns.relplot(data=d, x="PCA3", y="PCA4", kind="scatter", col="Sample", hue="mix", size=1, alpha=1)
